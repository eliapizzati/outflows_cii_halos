# %%
import os
from astropy.io import fits
from astropy.table import Table



#define the input file
input_filename = "ALPINE_merged_catalogs.fits"


#First, you can open the file and check the information in it
fits_table_hdu = fits.open(input_filename)

#...like the number of HDU, in this case 5
fits_table_hdu.info()


table_header = fits_table_hdu[1].header
table_data = fits_table_hdu[1].data


evt_data = Table(table_data)
print("Data contains %d events" % len(evt_data))
# Out:
# Filename: ALPINE_merged_catalogs.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU    217   118R x 85C   [100A, D, D, D, D, D, D, D, D, D, L, D, D, D, D, D, D, D, D, L, D, D, D, K, E, E, E, E, K, 20A, E, E, K, K, E, E, E, E, K, E, E, E, K, E, E, E, K, K, E, K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, K, E, E, E, E, E, E, E, E, E]
# Data contains 118 events

# %%
evt_data
# Out:
# <Table length=118>
#          name               CII_flux      ... log_sfrha_low log_sfrha_up
#         str100              float64       ...    float32      float32
# ---------------------- ------------------ ... ------------- ------------
#      CANDELS_GOODSS_12 0.8400254999999999 ...     0.8341427    1.7818204
#      CANDELS_GOODSS_14         0.14730722 ...         -99.0        -99.0
#      CANDELS_GOODSS_19                nan ...     2.2987247     2.746205
#      CANDELS_GOODSS_21         0.18852776 ...         -99.0        -99.0
#      CANDELS_GOODSS_32 1.3822856000000001 ...      2.118629     2.622273
#      CANDELS_GOODSS_37                nan ...   -0.04356911    1.2308853
#      CANDELS_GOODSS_38         0.31327468 ...         -99.0        -99.0
#      CANDELS_GOODSS_42         0.06599546 ...         -99.0        -99.0
#      CANDELS_GOODSS_47         0.16468659 ...         -99.0        -99.0
#      CANDELS_GOODSS_57                nan ...         -99.0        -99.0
# ...

# %%
evt_data[evt_data["name"] == "CANDELS_GOODSS_12"]["LCII"][0]
# Out:
# 500436489.2362836

# %%
evt_data.iloc(evt_data["name"] == "vuds_cosmos_5180966608")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b082b5b223d6> in <module>
# ----> 1 evt_data.iloc(evt_data["name"] == "vuds_cosmos_5180966608")
#
# ~\Anaconda3\lib\site-packages\astropy\table\table.py in iloc(self)
#     643         indexed rows in the order they appear in the index.
#     644         '''
# --> 645         return TableILoc(self)
#     646
#     647     def add_index(self, colnames, engine=None, unique=False):
#
# ~\Anaconda3\lib\site-packages\astropy\table\index.py in __init__(self, table)
#     942
#     943     def __init__(self, table):
# --> 944         super().__init__(table)
#     945
#     946     def __getitem__(self, item):
#
# ~\Anaconda3\lib\site-packages\astropy\table\index.py in __init__(self, table)
#     823         self.indices = table.indices
#     824         if len(self.indices) == 0:
# ...

# %%
table_header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  566 / length of dimension 1
# NAXIS2  =                  118 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   85 / number of table fields
# TTYPE1  = 'name    '
# TFORM1  = '100A    '
# TTYPE2  = 'CII_flux'
# TFORM2  = 'D       '
# TUNIT2  = 'Jy km s-1'
# TTYPE3  = 'unc_CII_flux'
# TFORM3  = 'D       '
# TUNIT3  = 'Jy km s-1'
# TTYPE4  = 'LCII    '
# TFORM4  = 'D       '
# TUNIT4  = 'solLum  '
# TTYPE5  = 'unc_LCII'
# TFORM5  = 'D       '
# TUNIT5  = 'solLum  '
# TTYPE6  = 'zCII    '
# TFORM6  = 'D       '
# TTYPE7  = 'unc_zCII'
# TFORM7  = 'D       '
# TTYPE8  = 'CII_FWHM'
# TFORM8  = 'D       '
# TUNIT8  = 'km s-1  '
# TTYPE9  = 'unc_CII_FWHM'
# TFORM9  = 'D       '
# ...

# %%
input_image_filename = "DEIMOS_COSMOS_683613.flux.clean.fits"

#First, you can open the file and check the information in it
fits_image_hdu = fits.open(input_image_filename)

#as before...
fits_image_hdu.info()

image_header = fits_image_hdu[0].header
image_data = fits_image_hdu[0].data


import matplotlib.pyplot as plt

plt.imshow(image_data[0,0,:,:], cmap='inferno')
plt.show()
# Out:
# Filename: DEIMOS_COSMOS_683613.flux.clean.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      93   (256, 256, 1, 1)   float32

# %%
image_header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                  256
# NAXIS2  =                  256
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BTYPE   = 'Intensity'
# OBJECT  = 'DEIMOS_COSMOS_683613'
# BUNIT   = 'Jy/beam.km/s'       /Brightness (pixel) unit
# RADESYS = 'ICRS    '
# LONPOLE =   1.800000000000E+02
# LATPOLE =   2.337183333333E+00
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC3_1   =   0.000000000000E+00
# PC4_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# PC3_2   =   0.000000000000E+00
# PC4_2   =   0.000000000000E+00
# PC1_3   =   0.000000000000E+00
# PC2_3   =   0.000000000000E+00
# PC3_3   =   1.000000000000E+00
# ...

# %%
input_image_filename = "CANDELS_GOODSS_32.flux.clean.fits"

#First, you can open the file and check the information in it
fits_image_hdu = fits.open(input_image_filename)

#as before...
fits_image_hdu.info()

image_header = fits_image_hdu[0].header
image_data = fits_image_hdu[0].data

image_header
# Out:
# Filename: CANDELS_GOODSS_32.flux.clean.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      93   (256, 256, 1, 1)   float32
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                  256
# NAXIS2  =                  256
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BTYPE   = 'Intensity'
# OBJECT  = 'CANDELS_GOODSS_32'
# BUNIT   = 'Jy/beam.km/s'       /Brightness (pixel) unit
# RADESYS = 'ICRS    '
# LONPOLE =   1.800000000000E+02
# LATPOLE =  -2.768714444444E+01
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC3_1   =   0.000000000000E+00
# PC4_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# ...

# %%
import matplotlib.pyplot as plt

plt.imshow(image_data[0,0,:,:], cmap='inferno')

# %%
input_image_filename = "CANDELS_GOODSS_32.psf.clean.fits"

#First, you can open the file and check the information in it
fits_image_hdu = fits.open(input_image_filename)

#as before...
fits_image_hdu.info()

image_header = fits_image_hdu[0].header
image_data = fits_image_hdu[0].data
# Out:
# Filename: CANDELS_GOODSS_32.psf.clean.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      91   (256, 256, 1, 1)   float32

# %%
import matplotlib.pyplot as plt

plt.imshow(image_data[0,0,:,:], cmap='inferno')
